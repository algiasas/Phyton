# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/algiasas/Phyton/blob/main/3.%20Skai%C4%8Diai%20ir%20matematika/3.%20Math%20biblioteka.ipynb)

# %% [markdown]
# # Math biblioteka

# %% [markdown]
# Math bibliotekoje pateikiamos standartinės matematinės konstantos ir funkcijos. Biblioteką  galite naudoti norėdami atlikti įvairius matematinius skaičiavimus, pvz., skaitinius, trigonometrinius, logaritminius ir eksponentinius skaičiavimus.
#
#
# Šiame skyrelyje apkalbėsime keletą konstantų ir funkcijų.

# %% [markdown]
# **math.pi**
#
# skaičius 𝜋 yra matematinė konstanta, kurios reikšmė lygi 3.14159. Importavus Math biblioteką, konstantos reikšmę galime gauti užrašydami math.pi

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# Skritulio plotą skaičiuojame pagal formulę ![Fiksavimas.JPG](data:image/jpeg;base64,...)
# Programoje rašytume:

# %%
import math
r = 2
print ("skritulio plotas lygus", math.pi*r**2)
# Out:
# skritulio plotas lygus 12.566370614359172

# %% [markdown]
# **math.tau**
# gražina 2π reikšmę

# %%
import math
print (math.tau)
# Out:
# 6.283185307179586

# %% [markdown]
# math.e - matematinė konstanta e (gražina e reikšmę)

# %%
import math
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# # ***Skaičių funkcijos***
# **math.ceil** - susieja slankiojo kablelio skaičių su artimiausiu didesniu  sveikuoju skaičiumi:

# %%
import math
print (math.ceil(10.12))
# Out:
# 11

# %% [markdown]
# **math.floor** - susieja slankiojo kablelio skaičių su artimiausiu mažesniu sveikuoju skaičiumi:

# %%
import math
print (math.floor(10.12))
# Out:
# 10

# %% [markdown]
# **math.factorial** - randa natūraliojo skaičiaus faktorialą (pvz., 5!=1*2*3*4*5)

# %%
import math
print (math.factorial(5))
# Out:
# 120

# %% [markdown]
# **math.gcd** - randa dviejų skaičių bendrą didžiausią daliklį:

# %%
import math
print (math.gcd(2,4))
# Out:
# 2

# %% [markdown]
# **math.pow** - skaičių x kelia n-uoju laipsniu:

# %%
import math
print (math.pow(2, 10))
# Out:
# 1024.0

# %% [markdown]
# **math.sqrt** - randa skaičiaus kavdratinę šaknį:

# %%
import math
print (math.sqrt (25))
# Out:
# 5.0

# %% [markdown]
# Norėdami rašyti tik funkcijų ar konstantų pavadinimus reikia pradžioje programos vietoj
# ```import math```
# rašyti
# ```from math import *```.
# Tada rašysime trumpiau:

# %%
from math import *
print(sqrt(25))
print(pi)
print(gcd(5, 120))
# Out:
# 5.0
# 3.141592653589793
# 5

# %% [markdown]
# # Užduotys

# %% [markdown]
# ## Užduotis 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#čia rašykite programos kodą

# %% [markdown]
# ## Užduotis 2
#
# ![image.png](data:image/png;base64,...)

# %%
# Kodą rašykite čia...

# %% [markdown]
# ## Užduotis 3
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
# Kodą rašykite čia...

# %% [markdown]
# ## Užduotis 4
#
# ![image.png](data:image/png;base64,...)
#
# Papildomos formulės skaičiamimams
# ![image.png](data:image/png;base64,...)

# %%
# Kodą rašykite čia...

# %% [markdown]
# ## Užduotis 5
# ![image.png](data:image/png;base64,...)

# %%
# Kodą rašykite čia...

# %% [markdown]
# ## Užduotis 6
# ![image.png](data:image/png;base64,...)
#
# Paaiškinimai:
# ![image.png](data:image/png;base64,...)

# %%
# Kodą rašykite čia...

# %% [markdown]
# ## Užduotis 7
# ![image.png](data:image/png;base64,...)

# %%
# Kodą rašykite čia...
